# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Test - example from class

# %%
filename = "/home/fhr2592/workspace/hw-physics390/cpp/probability/data/uniform.dat"

def show_file(filename):
    values = []

    with open(filename, "r") as f:
        for line in f:
            if "val: " in line:
                value = float(line.split("val: ")[1].strip())
                values.append(value)

    plt.hist(values, bins=100, edgecolor='black')
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    # plt.show()

    print("N ",len(values))
    print("mean", np.mean(values), "std",  np.std(values))
    print(values[:3])

show_file(filename)
plt.show()
# Out:
# N  250000
# mean -0.015135193684000002 std 2.8815065460812157
# [-2.09009, -4.374323, -0.502066]

# %%
from math import pi, sqrt

a=1

def show_mb_results(a):
    print(f"Showing MB results for {a=}")

    filename = f'/home/fhr2592/workspace/hw-physics390/cpp/probability/data/maxwell_boltzmann_rejection_a{a}.dat'
    show_file(filename)

    def get_mb_expected_stats(a):
        """Calculate expected statistics from a boltzman distribution (see https://en.wikipedia.org/wiki/Maxwell%E2%80%93Boltzmann_distribution#Distribution_function)"""
        mean = 2*a*sqrt(2/pi)
        var = a**2 * (3*pi-8) / pi
        std = sqrt(var)
        return mean, std

    expected_mean, expected_std = get_mb_expected_stats(a)
    print(f"{expected_mean=}", f"{expected_std=}", sep='\n')

for a in [1,2,5]:
    show_mb_results(a)

plt.show()
# Out:
# Showing MB results for a=1
# N  250000
# mean 1.5961589545880002 std 0.6738134966555575
# [1.693035, 2.269331, 2.143809]
# expected_mean=1.5957691216057308
# expected_std=0.6734396116428514
# Showing MB results for a=2
# N  250000
# mean 3.1889045507520004 std 1.3451009830691107
# [1.349626, 4.135877, 4.777152]
# expected_mean=3.1915382432114616
# expected_std=1.3468792232857028
# Showing MB results for a=5
# N  250000
# mean 7.959474795295999 std 3.341441036544262
# [6.535774, 8.425883, 6.837344]
# expected_mean=7.978845608028654
# expected_std=3.3671980582142567

# %%
from math import pi, sqrt

a=1

def show_mb_results(a):
    print(f"Showing MB results for {a=}")

    filename = f'/home/fhr2592/workspace/hw-physics390/cpp/probability/data/maxwell_boltzmann_metropolis_a{a}.dat'
    show_file(filename)

    def get_mb_expected_stats(a):
        """Calculate expected statistics from a boltzman distribution (see https://en.wikipedia.org/wiki/Maxwell%E2%80%93Boltzmann_distribution#Distribution_function)"""
        mean = 2*a*sqrt(2/pi)
        var = a**2 * (3*pi-8) / pi
        std = sqrt(var)
        return mean, std

    expected_mean, expected_std = get_mb_expected_stats(a)
    print(f"{expected_mean=}", f"{expected_std=}", sep='\n')

for a in [1,2,5]:
    show_mb_results(a)

plt.show()
# Out:
# Showing MB results for a=1
# N  200000
# mean 190.60941697994002 std 111.78432007179083
# [19.443689, 17.259031, 16.792844]
# expected_mean=1.5957691216057308
# expected_std=0.6734396116428514
# Showing MB results for a=2
# N  200000
# mean 158.35956020029997 std 95.64036429675086
# [3.572036, 3.94335, 3.94335]
# expected_mean=3.1915382432114616
# expected_std=1.3468792232857028
# Showing MB results for a=5
# N  200000
# mean 181.53247692129497 std 82.47685479542994
# [5.521682, 6.36732, 7.361298]
# expected_mean=7.978845608028654
# expected_std=3.3671980582142567
